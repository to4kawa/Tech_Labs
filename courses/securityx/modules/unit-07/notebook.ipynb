# %% [markdown]
# # Unit 07 Notebook\nテーマ: Engineering: セキュアCI/CD\nこのノートは Colab で証跡整理に使います。\n

# %% [markdown]
# ## 使い方\n1. Cloud ShellでREADMEのコマンドを実行\n2. 結果をこのノートへ貼り付け\n3. 最後にExplain-backを完成\n

# %%
# 実行コマンド記録用（編集して使う）\ncommands = [\n    'gcloud config get-value project',\n]\nfor c in commands:\n    print(c)\n

# %% [markdown]
# ## 証跡まとめ\n- 実行結果: \n- ログ確認: \n- 差分確認: \n

# %% [markdown]
# ## Explain-back下書き\n- 目的: \n- 検証に使ったログ: \n- 次回改善: \n
